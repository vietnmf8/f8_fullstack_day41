# %%
//src/services/product/index.js

export * from "./hooks";
export * from './services' // Bổ sung

# %%
// src/services/product/hooks.js

//...
import { getProducts } from "."; // "." thư mục hiện tại. Khi vào thư mục hiện tại sẽ tự động lấy file index
// => "." = "./index.js"

//...
